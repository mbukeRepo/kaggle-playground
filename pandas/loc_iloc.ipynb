# %%
import numpy as np

# %%
import pandas as pd

# %%
np.random.seed(101)
array = np.random.randint(10, 50, (10, 5))
df = pd.DataFrame(data = array, columns="VAL1 VAL2 VAL3 VAL4 VAL5".split(), index="A B C D E F G H I J".split(" "))

# %%
array.shape
# Out:
# (10, 5)

# %%
array
# Out:
# array([[41, 21, 27, 16, 33],
#        [21, 19, 23, 14, 38],
#        [10, 15, 22, 39, 29],
#        [18, 39, 44, 18, 29],
#        [20, 22, 41, 33, 10],
#        [19, 18, 46, 29, 45],
#        [38, 17, 20, 49, 48],
#        [19, 28, 17, 49, 25],
#        [10, 22, 27, 21, 25],
#        [43, 39, 34, 46, 29]])

# %%
df.head()
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# C    10    15    22    39    29
# D    18    39    44    18    29
# E    20    22    41    33    10

# %%
df.loc["A"]
# Out:
# VAL1    41
# VAL2    21
# VAL3    27
# VAL4    16
# VAL5    33
# Name: A, dtype: int64

# %%
df.loc["A": "D"]
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# C    10    15    22    39    29
# D    18    39    44    18    29

# %%
df.iloc[0: 4]
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# C    10    15    22    39    29
# D    18    39    44    18    29

# %%
# locating

# %%
df.loc["A", "VAL2"]
# Out:
# 21

# %%
df.loc["A": "C"]["VAL4"]
# Out:
# A    16
# B    14
# C    39
# Name: VAL4, dtype: int64

# %%
type(df.loc["A": "C"]["VAL4"])
# Out:
# pandas.core.series.Series

# %%
df.loc["A": "C"][["VAL4"]]
# Out:
#    VAL4
# A    16
# B    14
# C    39

# %%
type(df.loc["A": "C"][["VAL4"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[1: 3][["VAL4"]]
# Out:
#    VAL4
# B    14
# C    39

# %%
df
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# C    10    15    22    39    29
# D    18    39    44    18    29
# E    20    22    41    33    10
# F    19    18    46    29    45
# G    38    17    20    49    48
# H    19    28    17    49    25
# I    10    22    27    21    25
# J    43    39    34    46    29

# %%
df.iloc[2:5].loc["E": "F", ["VAL3"]]
# Out:
#    VAL3
# E    41

# %%
df.drop(["VAL1"], inplace=True, axis=1)

# %%
df
# Out:
#    VAL2  VAL3  VAL4  VAL5
# A    21    27    16    33
# B    19    23    14    38
# C    15    22    39    29
# D    39    44    18    29
# E    22    41    33    10
# F    18    46    29    45
# G    17    20    49    48
# H    28    17    49    25
# I    22    27    21    25
# J    39    34    46    29

# %%
df.drop(["A"], inplace=True, axis = 0)

# %%
df
# Out:
#    VAL2  VAL3  VAL4  VAL5
# B    19    23    14    38
# C    15    22    39    29
# D    39    44    18    29
# E    22    41    33    10
# F    18    46    29    45
# G    17    20    49    48
# H    28    17    49    25
# I    22    27    21    25
# J    39    34    46    29

# %%
df["VAL3"] = np.NaN

# %%
df
# Out:
#    VAL2  VAL3  VAL4  VAL5
# B    19   NaN    14    38
# C    15   NaN    39    29
# D    39   NaN    18    29
# E    22   NaN    33    10
# F    18   NaN    29    45
# G    17   NaN    49    48
# H    28   NaN    49    25
# I    22   NaN    21    25
# J    39   NaN    46    29

# %%
df.dropna(inplace=True, axis=1)

# %%
df
# Out:
#    VAL2  VAL4  VAL5
# B    19    14    38
# C    15    39    29
# D    39    18    29
# E    22    33    10
# F    18    29    45
# G    17    49    48
# H    28    49    25
# I    22    21    25
# J    39    46    29

# %%
df[] = np.NaN

# %%
df
# Out:
#    VAL2  VAL4  VAL5  (B, VAL2)
# B    19    14    38        NaN
# C    15    39    29        NaN
# D    39    18    29        NaN
# E    22    33    10        NaN
# F    18    29    45        NaN
# G    17    49    48        NaN
# H    28    49    25        NaN
# I    22    21    25        NaN
# J    39    46    29        NaN

# %%
df.drop([["B", "VAL2"]], inplace=True, axis=1)

# %%
df
# Out:
#    VAL2  VAL4  VAL5
# B    19    14    38
# C    15    39    29
# D    39    18    29
# E    22    33    10
# F    18    29    45
# G    17    49    48
# H    28    49    25
# I    22    21    25
# J    39    46    29
