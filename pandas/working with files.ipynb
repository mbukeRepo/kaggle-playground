# %%
# !pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 2.3 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/brain_networks.csv")

# %%
df.head()
# Out:
#   network                  1                1.1                   2  \
# 0    node                  1                  1                   1
# 1    hemi                 lh                 rh                  lh
# 2     NaN                NaN                NaN                 NaN
# 3       0  56.05574417114258  92.03103637695312   3.391575574874878
# 4       1   55.5472526550293   43.6900749206543  -65.49598693847656
#
#                    2.1                   3                 3.1  \
# 0                    1                   1                   1
# 1                   rh                  lh                  rh
# 2                  NaN                 NaN                 NaN
# 3    38.65968322753906  26.203819274902344  -49.71556854248047
# 4  -13.974522590637207  -28.27496337890625  -39.05012893676758
#
#                      4                  4.1                    5  ...  \
# 0                    1                    1                    1  ...
# ...

# %%
df.columns
# Out:
# Index(['network', '1', '1.1', '2', '2.1', '3', '3.1', '4', '4.1', '5', '5.1',
#        '6', '6.1', '6.2', '6.3', '7', '7.1', '7.2', '7.3', '7.4', '7.5', '8',
#        '8.1', '8.2', '8.3', '8.4', '8.5', '9', '9.1', '10', '10.1', '11',
#        '11.1', '12', '12.1', '12.2', '12.3', '12.4', '13', '13.1', '13.2',
#        '13.3', '13.4', '13.5', '14', '14.1', '15', '15.1', '16', '16.1',
#        '16.2', '16.3', '16.4', '16.5', '16.6', '16.7', '17', '17.1', '17.2',
#        '17.3', '17.4', '17.5', '17.6'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 923 entries, 0 to 922
# Data columns (total 63 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   network  922 non-null    object
#  1   1        922 non-null    object
#  2   1.1      922 non-null    object
#  3   2        922 non-null    object
#  4   2.1      922 non-null    object
#  5   3        922 non-null    object
#  6   3.1      922 non-null    object
#  7   4        922 non-null    object
#  8   4.1      922 non-null    object
#  9   5        922 non-null    object
#  10  5.1      922 non-null    object
#  11  6        922 non-null    object
#  12  6.1      922 non-null    object
#  13  6.2      922 non-null    object
#  14  6.3      922 non-null    object
#  15  7        922 non-null    object
#  16  7.1      922 non-null    object
#  17  7.2      922 non-null    object
#  18  7.3      922 non-null    object
#  19  7.4      922 non-null    object
# ...

# %%
pd.to_csv?
# Out:
# Object `pd.to_csv` not found.

# %%
# Out:
# <bound method NDFrame.to_csv of     network                    1                  1.1                   2  \
# 0      node                    1                    1                   1
# 1      hemi                   lh                   rh                  lh
# 2       NaN                  NaN                  NaN                 NaN
# 3         0    56.05574417114258    92.03103637695312   3.391575574874878
# 4         1     55.5472526550293     43.6900749206543  -65.49598693847656
# ..      ...                  ...                  ...                 ...
# 918     915  -7.4295125007629395    -4.81321907043457  -3.670536518096924
# 919     916   -33.55413818359375   -38.60562133789063  -25.66480255126953
# 920     917   -78.53956604003906   -74.19718933105469  -54.04159545898438
# 921     918  -103.23582458496094    -98.7442855834961  -40.10954284667969
# 922     919   -36.28886795043945  -10.762069702148438  -30.35626220703125
#
# ...

# %%
df[["17"]]
# Out:
#                       17
# 0                      1
# 1                     lh
# 2                    NaN
# 3     -21.73455047607422
# 4    -13.035799026489258
# ..                   ...
# 918    76.17948913574219
# 919    50.96239852905274
# 920    43.80074691772461
# 921    46.67441940307617
# 922  -12.229619979858398
#
# [923 rows x 1 columns]

# %%
df[["17"]].to_csv("file.csv")

# %%
pd.read_excel("https://github.com/DataForScience/Excel/raw/master/data/Simple.xlsx").shape
# Out:
# (12, 2)

# %%
df[["17"]].to_excel("file.xlsx", sheet_name="hello")
